# %%
import pandas as pd
df = pd.read_excel('downloads/SemifinalMerge.xlsx')
df.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0             Iowa                    19000              136.9
# 1    United States                        0              129.8
# 2  Harrison County                    19085              187.3
# 3    Howard County                    19089              182.8
# 4  Cherokee County                    19035              171.6
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                2692              rising                 125.9
# 1              258398              rising                 113.2
# 2                  19              rising                 158.9
# 3                  11              stable                 127.7
# 4                  14              rising                 174.6
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                   2594                rising             54.3
# 1                 224883                rising             48.4
# ...

# %% [markdown]
# # IMPORTING HEALTH FACTOR DATA

# %%
# Depression sets
depressionbc = pd.read_excel('downloads/depressionbreastcancer.xlsx')
depressionlc = pd.read_excel('downloads/depressionlungcancer.xlsx')
depressionmel = pd.read_excel('downloads/depressionmelanoma.xlsx')
depressionpro = pd.read_excel('downloads/depressionprostate.xlsx')

# %% [markdown]
# ## Merging depression data to set

# %%
merged = pd.merge(df, depressionbc, on='County', how='outer')  
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0             Iowa                  19000.0              136.9
# 1    United States                      0.0              129.8
# 2  Harrison County                  19085.0              187.3
# 3  Harrison County                  19085.0              187.3
# 4    Howard County                  19089.0              182.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                2692              rising                 125.9
# 1              258398              rising                 113.2
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  11              stable                 127.7
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                 2594.0                rising             54.3
# 1               224883.0                rising             48.4
# ...

# %%
merged = pd.merge(merged, depressionlc, on='County', how='outer')
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0             Iowa                  19000.0              136.9
# 1    United States                      0.0              129.8
# 2  Harrison County                  19085.0              187.3
# 3  Harrison County                  19085.0              187.3
# 4  Harrison County                  19085.0              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                2692              rising                 125.9
# 1              258398              rising                 113.2
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                 2594.0                rising             54.3
# 1               224883.0                rising             48.4
# ...

# %%
merged.drop('Unnamed: 0_x', axis=1, inplace=True)
merged.drop('Unnamed: 0_y', axis=1, inplace=True)
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0             Iowa                  19000.0              136.9
# 1    United States                      0.0              129.8
# 2  Harrison County                  19085.0              187.3
# 3  Harrison County                  19085.0              187.3
# 4  Harrison County                  19085.0              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                2692              rising                 125.9
# 1              258398              rising                 113.2
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                 2594.0                rising             54.3
# 1               224883.0                rising             48.4
# ...

# %%
merged = pd.merge(merged, depressionmel, on='County', how='outer')
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0             Iowa                  19000.0              136.9
# 1    United States                      0.0              129.8
# 2  Harrison County                  19085.0              187.3
# 3  Harrison County                  19085.0              187.3
# 4  Harrison County                  19085.0              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                2692              rising                 125.9
# 1              258398              rising                 113.2
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                 2594.0                rising             54.3
# 1               224883.0                rising             48.4
# ...

# %%
merged.drop('Unnamed: 0', axis=1, inplace=True)
merged.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 merged.drop('Unnamed: 0', axis=1, inplace=True)
#       2 merged.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
# ...

# %%
merged = pd.merge(merged, depressionpro, on='County', how='outer')
merged.drop('Unnamed: 0', axis=1, inplace=True)
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0             Iowa                  19000.0              136.9
# 1    United States                      0.0              129.8
# 2  Harrison County                  19085.0              187.3
# 3  Harrison County                  19085.0              187.3
# 4  Harrison County                  19085.0              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                2692              rising                 125.9
# 1              258398              rising                 113.2
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                 2594.0                rising             54.3
# 1               224883.0                rising             48.4
# ...

# %% [markdown]
# ## Merging diabetes data to set

# %%
diabetesbc = pd.read_excel('downloads/diabetesbreast.xlsx')
diabeteslung = pd.read_excel('downloads/diabeteslungcorrect.xlsx')
diabetesmel = pd.read_excel('downloads/diabetesmelanoma.xlsx')
diabetespro = pd.read_excel('downloads/diabetesprostate.xlsx')

# %%
merged = pd.merge(merged, diabetesbc, on='County', how='outer')
merged.drop('Unnamed: 0', axis=1, inplace=True)
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0             Iowa                  19000.0              136.9
# 1    United States                      0.0              129.8
# 2  Harrison County                  19085.0              187.3
# 3  Harrison County                  19085.0              187.3
# 4  Harrison County                  19085.0              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                2692              rising                 125.9
# 1              258398              rising                 113.2
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                 2594.0                rising             54.3
# 1               224883.0                rising             48.4
# ...

# %%
merged = pd.merge(merged, diabeteslung, on='County', how='outer')
merged.drop('Unnamed: 0', axis=1, inplace=True)
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0             Iowa                  19000.0              136.9
# 1    United States                      0.0              129.8
# 2  Harrison County                  19085.0              187.3
# 3  Harrison County                  19085.0              187.3
# 4  Harrison County                  19085.0              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                2692              rising                 125.9
# 1              258398              rising                 113.2
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                 2594.0                rising             54.3
# 1               224883.0                rising             48.4
# ...

# %%
merged = pd.merge(merged, diabetesmel, on='County', how='outer')
merged.drop('Unnamed: 0', axis=1, inplace=True)
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0             Iowa                  19000.0              136.9
# 1    United States                      0.0              129.8
# 2  Harrison County                  19085.0              187.3
# 3  Harrison County                  19085.0              187.3
# 4  Harrison County                  19085.0              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                2692              rising                 125.9
# 1              258398              rising                 113.2
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                 2594.0                rising             54.3
# 1               224883.0                rising             48.4
# ...

# %%
merged = pd.merge(merged, diabetespro, on='County', how='outer')
merged.drop('Unnamed: 0', axis=1, inplace=True)
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0             Iowa                  19000.0              136.9
# 1    United States                      0.0              129.8
# 2  Harrison County                  19085.0              187.3
# 3  Harrison County                  19085.0              187.3
# 4  Harrison County                  19085.0              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                2692              rising                 125.9
# 1              258398              rising                 113.2
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                 2594.0                rising             54.3
# 1               224883.0                rising             48.4
# ...

# %% [markdown]
# ## Drop duplicate columns

# %%
merged = merged.drop_duplicates(subset='County', keep='first')

# %%
merged.head()
# Out:
#                 County  FIPS (County ID Number) Breast Cancer Rate  \
# 0                 Iowa                  19000.0              136.9
# 1        United States                      0.0              129.8
# 2      Harrison County                  19085.0              187.3
# 32770    Howard County                  19089.0              182.8
# 65538  Cherokee County                  19035.0              171.6
#
#       Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                    2692              rising                 125.9
# 1                  258398              rising                 113.2
# 2                      19              rising                 158.9
# 32770                  11              stable                 127.7
# 65538                  14              rising                 174.6
#
#        Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                     2594.0                rising             54.3
# ...

# %% [markdown]
# ## Merging high blood pressure data to set

# %%
bpbreast = pd.read_excel('downloads/breasthighBP.xlsx')
bplung = pd.read_excel('downloads/lunghighBP.xlsx')
bpmel = pd.read_excel('downloads/melanomahighBP.xlsx')
bppro = pd.read_excel('downloads/prostatehighBP.xlsx')

# %%
merged = pd.merge(merged, bpbreast, on='County', how='outer')
merged.drop('Unnamed: 0', axis=1, inplace=True)
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0             Iowa                  19000.0              136.9
# 1    United States                      0.0              129.8
# 2  Harrison County                  19085.0              187.3
# 3  Harrison County                  19085.0              187.3
# 4    Howard County                  19089.0              182.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                2692              rising                 125.9
# 1              258398              rising                 113.2
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  11              stable                 127.7
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                 2594.0                rising             54.3
# 1               224883.0                rising             48.4
# ...

# %%
merged = pd.merge(merged, bplung, on='County', how='outer')
merged.drop('Unnamed: 0', axis=1, inplace=True)
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0             Iowa                  19000.0              136.9
# 1    United States                      0.0              129.8
# 2  Harrison County                  19085.0              187.3
# 3  Harrison County                  19085.0              187.3
# 4  Harrison County                  19085.0              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                2692              rising                 125.9
# 1              258398              rising                 113.2
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                 2594.0                rising             54.3
# 1               224883.0                rising             48.4
# ...

# %%
merged = pd.merge(merged, bpmel, on='County', how='inner')
merged.drop('Unnamed: 0', axis=1, inplace=True)
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0  Harrison County                    19085              187.3
# 1  Harrison County                    19085              187.3
# 2  Harrison County                    19085              187.3
# 3  Harrison County                    19085              187.3
# 4  Harrison County                    19085              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 1                  19              rising                 158.9
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                     18                stable             62.5
# 1                     18                stable             62.5
# ...

# %%
merged = pd.merge(merged, bppro, on='County', how='inner')
merged.drop('Unnamed: 0', axis=1, inplace=True)
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0  Harrison County                    19085              187.3
# 1  Harrison County                    19085              187.3
# 2  Harrison County                    19085              187.3
# 3  Harrison County                    19085              187.3
# 4  Harrison County                    19085              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 1                  19              rising                 158.9
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                     18                stable             62.5
# 1                     18                stable             62.5
# ...

# %%
merged = merged.rename(columns={'% Melanoma Patients With High Blood Pressure_y': '% Prostate Cancer Patients With High Blood Pressure_y'})

# %% [markdown]
# ## Merging high cholesterol data to set

# %%
highbreast = pd.read_excel('downloads/highchobreast.xlsx')
highlung = pd.read_excel('downloads/highcholung.xlsx')
highmel = pd.read_excel('downloads/highchomelanoma.xlsx')
highpro = pd.read_excel('downloads/highchoprostate.xlsx')

# %%
merged = pd.merge(merged, highbreast, on='County', how='inner')
merged.drop('Unnamed: 0', axis=1, inplace=True)
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0  Harrison County                    19085              187.3
# 1  Harrison County                    19085              187.3
# 2  Harrison County                    19085              187.3
# 3  Harrison County                    19085              187.3
# 4  Harrison County                    19085              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 1                  19              rising                 158.9
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                     18                stable             62.5
# 1                     18                stable             62.5
# ...

# %%
merged.drop('% Breast Cancer Patients With High Cholesterol_y', axis=1, inplace=True)
merged.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 merged.drop('% Breast Cancer Patients With High Cholesterol_y', axis=1, inplace=True)
#       2 merged.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...

# %%
merged = pd.merge(merged, highlung, on='County', how='inner')
merged.drop('Unnamed: 0', axis=1, inplace=True)
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0  Harrison County                    19085              187.3
# 1  Harrison County                    19085              187.3
# 2  Harrison County                    19085              187.3
# 3  Harrison County                    19085              187.3
# 4  Harrison County                    19085              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 1                  19              rising                 158.9
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                     18                stable             62.5
# 1                     18                stable             62.5
# ...

# %%
merged = pd.merge(merged, highmel, on='County', how='inner')
merged.drop('Unnamed: 0', axis=1, inplace=True)
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0  Harrison County                    19085              187.3
# 1  Harrison County                    19085              187.3
# 2  Harrison County                    19085              187.3
# 3  Harrison County                    19085              187.3
# 4  Harrison County                    19085              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 1                  19              rising                 158.9
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                     18                stable             62.5
# 1                     18                stable             62.5
# ...

# %%
merged = pd.merge(merged, highpro, on='County', how='inner')
merged.drop('Unnamed: 0', axis=1, inplace=True)
merged.head()
# Out:
#             County  FIPS (County ID Number) Breast Cancer Rate  \
# 0  Harrison County                    19085              187.3
# 1  Harrison County                    19085              187.3
# 2  Harrison County                    19085              187.3
# 3  Harrison County                    19085              187.3
# 4  Harrison County                    19085              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 1                  19              rising                 158.9
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  \
# 0                     18                stable             62.5
# 1                     18                stable             62.5
# ...

# %%
merged.to_csv('Mergedinprogress.csv')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 merged.to_csv('Mergedinprogress.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
# ...

# %% [markdown]
# ## Merging heart disease data with set

# %%
# reimport as csv
df2 = pd.read_csv('Mergedinprogress.csv')
df2.head()
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_8380\1206229967.py:2: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('Mergedinprogress.csv')
#    Unnamed: 0           County  FIPS (County ID Number)  Breast Cancer Rate  \
# 0           0  Harrison County                    19085               187.3
# 1           1  Harrison County                    19085               187.3
# 2           2  Harrison County                    19085               187.3
# 3           3  Harrison County                    19085               187.3
# 4           4  Harrison County                    19085               187.3
#
#    Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                   19              rising                 158.9
# 1                   19              rising                 158.9
# 2                   19              rising                 158.9
# ...
