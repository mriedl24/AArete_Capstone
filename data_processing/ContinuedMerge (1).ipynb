# %%
import pandas as pd

# %%
# import dataset
dataset = pd.read_excel('PreliminaryDataset.xlsx')
dataset.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 1           1    Howard County                    19089              182.8
# 2           2  Cherokee County                    19035              171.6
# 3           3    Keokuk County                    19107              169.9
# 4           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 1                  11              stable                 127.7
# 2                  14              rising                 174.6
# 3                  11              stable                  87.1
# 4                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
# importing and cleaning obesity sets
obesebc = pd.read_csv('downloads/data_download.csv')
obesebc.head()
# Out:
#    GEOID            County State              measure  value
# 0  19001      Adair County  Iowa  Obese (BMI over 30)  0.416
# 1  19003      Adams County  Iowa  Obese (BMI over 30)  0.383
# 2  19005  Allamakee County  Iowa  Obese (BMI over 30)  0.380
# 3  19007  Appanoose County  Iowa  Obese (BMI over 30)  0.432
# 4  19009    Audubon County  Iowa  Obese (BMI over 30)  0.411

# %%
obesebc.drop('GEOID', axis=1, inplace=True)
obesebc.drop('measure', axis=1, inplace=True)
obesebc.head()
# Out:
#              County State  value
# 0      Adair County  Iowa  0.416
# 1      Adams County  Iowa  0.383
# 2  Allamakee County  Iowa  0.380
# 3  Appanoose County  Iowa  0.432
# 4    Audubon County  Iowa  0.411

# %%
obesebc.drop('State', axis=1, inplace=True)
obesebc.head()
# Out:
#              County  value
# 0      Adair County  0.416
# 1      Adams County  0.383
# 2  Allamakee County  0.380
# 3  Appanoose County  0.432
# 4    Audubon County  0.411

# %%
obesebc = obesebc.rename(columns={'value': '% Breast Cancer Patients Who Are Obese (BMI>30)'})
obesebc.head()
# Out:
#              County  % Breast Cancer Patients Who Are Obese (BMI>30)
# 0      Adair County                                            0.416
# 1      Adams County                                            0.383
# 2  Allamakee County                                            0.380
# 3  Appanoose County                                            0.432
# 4    Audubon County                                            0.411

# %%
merged = pd.merge(dataset, obesebc, on='County', how='inner')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 1           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 3           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 1                  19              rising                 158.9
# 2                  11              stable                 127.7
# 3                  11              stable                 127.7
# 4                  14              rising                 174.6
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
obeselung3 = pd.read_csv('downloads/data_download (1).csv')
obeselung3.drop('GEOID', axis=1, inplace=True)
obeselung3.drop('measure', axis=1, inplace=True)
obeselung3.drop('State', axis=1, inplace=True)
obeselung3 = obeselung3.rename(columns={'value': '% Lung Cancer Patients Who Are Obese (BMI>30)'})
obeselung3.head()
# Out:
#              County  % Lung Cancer Patients Who Are Obese (BMI>30)
# 0      Adair County                                          0.416
# 1      Adams County                                          0.383
# 2  Allamakee County                                          0.380
# 3  Appanoose County                                          0.432
# 4    Audubon County                                          0.411

# %%
merged = pd.merge(merged, obeselung3, on='County', how='inner')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 1           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 3           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 1                  19              rising                 158.9
# 2                  11              stable                 127.7
# 3                  11              stable                 127.7
# 4                  14              rising                 174.6
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
obesemel = pd.read_csv('downloads/data_download (2).csv')
obesemel.drop('GEOID', axis=1, inplace=True)
obesemel.drop('measure', axis=1, inplace=True)
obesemel.drop('State', axis=1, inplace=True)
obesemel = obesemel.rename(columns={'value': '% Melanoma Patients Who Are Obese (BMI>30)'})
obesemel.head()
# Out:
#              County  % Melanoma Patients Who Are Obese (BMI>30)
# 0      Adair County                                       0.416
# 1      Adams County                                       0.383
# 2  Allamakee County                                       0.380
# 3  Appanoose County                                       0.432
# 4    Audubon County                                       0.411

# %%
merged = pd.merge(merged, obesemel, on='County', how='inner')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 1           0  Harrison County                    19085              187.3
# 2           0  Harrison County                    19085              187.3
# 3           0  Harrison County                    19085              187.3
# 4           1    Howard County                    19089              182.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 1                  19              rising                 158.9
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  11              stable                 127.7
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
obesepro = pd.read_csv('downloads/data_download (3).csv')
obesepro.drop('GEOID', axis=1, inplace=True)
obesepro.drop('measure', axis=1, inplace=True)
obesepro.drop('State', axis=1, inplace=True)
obesepro = obesepro.rename(columns={'value': '% Prostate Cancer Patients Who Are Obese (BMI>30)'})
obesepro.head()
# Out:
#              County  % Prostate Cancer Patients Who Are Obese (BMI>30)
# 0      Adair County                                              0.416
# 1      Adams County                                              0.383
# 2  Allamakee County                                              0.380
# 3  Appanoose County                                              0.432
# 4    Audubon County                                              0.411

# %%
merged = pd.merge(merged, obesepro, on='County', how='inner')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 1           0  Harrison County                    19085              187.3
# 2           0  Harrison County                    19085              187.3
# 3           0  Harrison County                    19085              187.3
# 4           0  Harrison County                    19085              187.3
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 1                  19              rising                 158.9
# 2                  19              rising                 158.9
# 3                  19              rising                 158.9
# 4                  19              rising                 158.9
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#     Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0            0  Harrison County                    19085              187.3
# 8            1    Howard County                    19089              182.8
# 16           2  Cherokee County                    19035              171.6
# 24           3    Keokuk County                    19107              169.9
# 32           4      Tama County                    19171              168.8
#
#    Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                   19              rising                 158.9
# 8                   11              stable                 127.7
# 16                  14              rising                 174.6
# 24                  11              stable                  87.1
# 32                  17              stable                 139.0
#
#     Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
activityb = pd.read_csv('downloads/data_download (4).csv')
activityb.drop('GEOID', axis=1, inplace=True)
activityb.drop('measure', axis=1, inplace=True)
activityb.drop('State', axis=1, inplace=True)
activityb = activityb.rename(columns={'value': '% Breast Cancer Patients Who Report Physical Inactivity'})
activityb.head()
# Out:
#              County  % Breast Cancer Patients Who Report Physical Inactivity
# 0      Adair County                                              0.280
# 1      Adams County                                              0.268
# 2  Allamakee County                                              0.290
# 3  Appanoose County                                              0.319
# 4    Audubon County                                              0.289

# %%
merged = pd.merge(merged, activityb, on='County', how='inner')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 1           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 3           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 1                  19              rising                 158.9
# 2                  11              stable                 127.7
# 3                  11              stable                 127.7
# 4                  14              rising                 174.6
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
activitymel = pd.read_csv('downloads/data_download (5).csv')
activitymel.drop('GEOID', axis=1, inplace=True)
activitymel.drop('measure', axis=1, inplace=True)
activitymel.drop('State', axis=1, inplace=True)
activitymel = activitymel.rename(columns={'value': '% Melanoma Patients Who Report Physical Inactivity'})
activitymel.head()
# Out:
#              County  % Melanoma Patients Who Report Physical Inactivity
# 0      Adair County                                              0.280
# 1      Adams County                                              0.268
# 2  Allamakee County                                              0.290
# 3  Appanoose County                                              0.319
# 4    Audubon County                                              0.289

# %%
merged = pd.merge(merged, activitymel, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#     Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0            0  Harrison County                    19085              187.3
# 4            1    Howard County                    19089              182.8
# 8            2  Cherokee County                    19035              171.6
# 12           3    Keokuk County                    19107              169.9
# 16           4      Tama County                    19171              168.8
#
#    Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                   19              rising                 158.9
# 4                   11              stable                 127.7
# 8                   14              rising                 174.6
# 12                  11              stable                  87.1
# 16                  17              stable                 139.0
#
#     Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
activitylung = pd.read_csv('downloads/data_download (6).csv')
activitylung.drop('GEOID', axis=1, inplace=True)
activitylung.drop('measure', axis=1, inplace=True)
activitylung.drop('State', axis=1, inplace=True)
activitylung = activitylung.rename(columns={'value': '% Lung Cancer Patients Who Report Physical Inactivity'})

# %%
merged = pd.merge(merged, activitylung, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
activitypro = pd.read_csv('downloads/data_download (7).csv')
activitypro.drop('GEOID', axis=1, inplace=True)
activitypro.drop('measure', axis=1, inplace=True)
activitypro.drop('State', axis=1, inplace=True)
activitypro = activitypro.rename(columns={'value': '% Prostate Cancer Patients Who Report Physical Inactivity'})

# %%
merged = pd.merge(merged, activitypro, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
bingebreast = pd.read_csv('downloads/data_download (8).csv')
bingebreast.drop('GEOID', axis=1, inplace=True)
bingebreast.drop('measure', axis=1, inplace=True)
bingebreast.drop('State', axis=1, inplace=True)
bingebreast = bingebreast.rename(columns={'value': '% Breast Cancer Patients Who Report Binge Drinking'})

# %%
merged = pd.merge(merged, bingebreast, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
bingelung = pd.read_csv('downloads/data_download (9).csv')
bingelung.drop('GEOID', axis=1, inplace=True)
bingelung.drop('measure', axis=1, inplace=True)
bingelung.drop('State', axis=1, inplace=True)
bingelung = bingelung.rename(columns={'value': '% Lung Cancer Patients Who Report Binge Drinking'})

# %%
merged = pd.merge(merged, bingelung, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
bingemel = pd.read_csv('downloads/data_download (10).csv')
bingemel.drop('GEOID', axis=1, inplace=True)
bingemel.drop('measure', axis=1, inplace=True)
bingemel.drop('State', axis=1, inplace=True)
bingemel = bingemel.rename(columns={'value': '% Melanoma Patients Who Report Binge Drinking'})

# %%
merged = pd.merge(merged, bingemel, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
bingepro = pd.read_csv('downloads/data_download (11).csv')
bingepro.drop('GEOID', axis=1, inplace=True)
bingepro.drop('measure', axis=1, inplace=True)
bingepro.drop('State', axis=1, inplace=True)
bingepro = bingepro.rename(columns={'value': '% Prostate Cancer Patients Who Report Binge Drinking'})

# %%
merged = pd.merge(merged, bingepro, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
sleepb = pd.read_csv('downloads/data_download (12).csv')
sleepb.drop('GEOID', axis=1, inplace=True)
sleepb.drop('measure', axis=1, inplace=True)
sleepb.drop('State', axis=1, inplace=True)
sleepb = sleepb.rename(columns={'value': '% Breast Cancer Patients Who Report <7Hrs/Night Sleep'})

# %%
merged = pd.merge(merged, sleepb, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
sleepl = pd.read_csv('downloads/data_download (13).csv')
sleepl.drop('GEOID', axis=1, inplace=True)
sleepl.drop('measure', axis=1, inplace=True)
sleepl.drop('State', axis=1, inplace=True)
sleepl = sleepl.rename(columns={'value': '% Lung Cancer Patients Who Report <7Hrs/Night Sleep'})

# %%
merged = pd.merge(merged, sleepl, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
sleepm = pd.read_csv('downloads/data_download (14).csv')
sleepm.drop('GEOID', axis=1, inplace=True)
sleepm.drop('measure', axis=1, inplace=True)
sleepm.drop('State', axis=1, inplace=True)
sleepm = sleepm.rename(columns={'value': '% Melanoma Patients Who Report <7Hrs/Night Sleep'})

# %%
merged = pd.merge(merged, sleepm, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
sleepp = pd.read_csv('downloads/data_download (15).csv')
sleepp.drop('GEOID', axis=1, inplace=True)
sleepp.drop('measure', axis=1, inplace=True)
sleepp.drop('State', axis=1, inplace=True)
sleepp = sleepp.rename(columns={'value': '% Prostate Cancer Patients Who Report <7Hrs/Night Sleep'})

# %%
merged = pd.merge(merged, sleepp, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
historyb = pd.read_csv('downloads/data_download (16).csv')
historyb.drop('GEOID', axis=1, inplace=True)
historyb.drop('measure', axis=1, inplace=True)
historyb.drop('State', axis=1, inplace=True)
historyb = historyb.rename(columns={'value': '% Breast Cancer Patients With History of Cancer Diagnosis'})

# %%
merged = pd.merge(merged, historyb, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
historyl = pd.read_csv('downloads/data_download (17).csv')
historyl.drop('GEOID', axis=1, inplace=True)
historyl.drop('measure', axis=1, inplace=True)
historyl.drop('State', axis=1, inplace=True)
historyl = historyl.rename(columns={'value': '% Lung Cancer Patients With History of Cancer Diagnosis'})

# %%
merged = pd.merge(merged, historyl, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
historym = pd.read_csv('downloads/data_download (18).csv')
historym.drop('GEOID', axis=1, inplace=True)
historym.drop('measure', axis=1, inplace=True)
historym.drop('State', axis=1, inplace=True)
historym = historym.rename(columns={'value': '% Melanoma Patients With History of Cancer Diagnosis'})

# %%
merged = pd.merge(merged, historym, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
historyp = pd.read_csv('downloads/data_download (19).csv')
historyp.drop('GEOID', axis=1, inplace=True)
historyp.drop('measure', axis=1, inplace=True)
historyp.drop('State', axis=1, inplace=True)
historyp = historyp.rename(columns={'value': '% Prostate Cancer Patients With History of Cancer Diagnosis'})

# %%
merged = pd.merge(merged, historyp, on='County', how='inner')
merged = merged.drop_duplicates(subset='County', keep='first')
merged.head()
# Out:
#    Unnamed: 0           County  FIPS (County ID Number) Breast Cancer Rate  \
# 0           0  Harrison County                    19085              187.3
# 2           1    Howard County                    19089              182.8
# 4           2  Cherokee County                    19035              171.6
# 6           3    Keokuk County                    19107              169.9
# 8           4      Tama County                    19171              168.8
#
#   Breast Cancer Count Breast Cancer Trend  Prostate Cancer Rate  \
# 0                  19              rising                 158.9
# 2                  11              stable                 127.7
# 4                  14              rising                 174.6
# 6                  11              stable                  87.1
# 8                  17              stable                 139.0
#
#    Prostate Cancer Count Prostate Cancer Trend Lung Cancer Rate  ...  \
# ...

# %%
merged.to_excel('FinalDataset.xlsx')
